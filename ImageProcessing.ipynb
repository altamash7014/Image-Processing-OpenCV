# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
img = np.array([
    [0,0,0],
    [0,1,0],
    [0,0,0]
])

plt.imshow(img)
plt.show()

# %%
board = np.zeros((8,8))

for i in range(8):
    for j in range(8):
        if (i + j) % 2 == 0:
            board[i][j] = 1

plt.imshow(board)
plt.show()

# %%
img = []

for i in range(720):
    temp = []
    for j in range(1280):
        temp.append(1)
    img.append(temp)

img = np.array(img)
plt.imshow(img)
plt.show()

# %%
img = np.ones((720,1280), dtype=np.uint8) * 255
cv.imwrite("whiteqqqq.png", img)
# Out:
# True

# %%
img = np.ones((720,1280), dtype=np.uint8) * 100
cv.imwrite("gray.png", img)
# Out:
# True

# %%
arr1 = np.array([[[0,0,0],[255,255,255],[0,0,0]],
               [[255,255,255],[0,0,0],[255,255,255]],
               [[0,0,0],[255,255,255],[0,0,0]]]
              )
plt.imshow(arr1)

# %%
cv.imwrite("chess.png", arr1)
# Out:
# True

# %%
# defining image2
img2=[]

for i in range(256):
    temp=[]
    for j in range(256):
        temp.append(i)
    img2.append(temp)

img2 = np.array(img2)
cv.imwrite("Shades of Grey.png",img2)
# Out:
# True

# %% [markdown]
# RED G B = [255,0,0]
# R GREEN B = [0,255,0]
# R G BLUE = [0,0,255]

# %%
arr2 = np.array([[[255,0,0],[255,0,0],[255,0,0]],
               [[255,0,0],[255,0,0],[255,0,0]],
               [[255,0,0],[255,0,0],[255,0,0]]])
cv.imwrite("Red.png",arr2)
# Out:
# True

# %%
plt.imshow(arr2)

# %% [markdown]
# during exporting with cv.imwrite
# rgb changes to bgr meand red changes to blue and viceversa

# %% [markdown]
# TO PREVENT WE WILL USE cv.cvtColor(img3,cv.COLOR_BGR2RGB)

# %%
img3 = cv.imread("Red.png.jpeg")

# %%
arr2 = cv.imread("Red.png")

if arr2 is None:
    print("Image not found or path incorrect")
else:
    arr2 = cv.cvtColor(arr2, cv.COLOR_BGR2RGB)

# %%
cv.imwrite("RedREAL.png",arr2)
# Out:
# True

# %%
arr4 = np.array([[[ 0, 30  , 0  ] , [ 0, 60  , 0 ] ,[ 0, 90  , 0 ]],
                [[ 0, 120 , 0  ] , [ 0, 150 , 0 ] ,[ 0, 180 , 0 ]],
                [[ 0, 210 , 0  ] , [ 0, 240 , 0 ] ,[ 0, 255 , 0 ]]])
plt.imshow(arr4)

# %%
arr5 = np.array([[[ 0,0, 30  ] , [ 0,0, 60  ] ,[ 0,0, 90  ]],
                [[ 0,0, 120 ] , [ 0,0, 150 ] ,[ 0,0, 180 ]],
                [[ 0,0, 210 ] , [ 0,0, 240 ] ,[ 0,0, 255 ]]])
plt.imshow(arr5)

# %%
imgR = []

for i in range(256):
    t = []
    for j in range(256):
        t.append([i,0,0])
    imgR.append(t)

imgR = np.array(imgR)

plt.imshow(imgR)

# %%
cv.imwrite("Shades of Red.png",imgR)
# Out:
# True

# %%
print(imgR.dtype)
print(imgR.shape)
# Out:
# int64
# (256, 256, 3)

# %%
imgR = imgR.astype('uint8')

# %%
cv.imshow("ghhhShades of Red34.png", imgR)
cv.waitKey(0)
cv.destroyAllWindows()
